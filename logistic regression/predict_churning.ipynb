# %%
import pandas as pd
from google.colab import drive

drive.mount ('/content/gdrive')

dta_churn = pd.read_csv('/content/gdrive/My Drive/Colab Notebooks/train_churn (1).csv')

churn = pd.read_csv('/content/gdrive/My Drive/Colab Notebooks/predict_churn.csv')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
dta_churn.head(19) # print the first 19 records
# Out:
#      X1   X2   X3   X4   X5  X6     X7  ...  X14    X15   X16  X17   X18  X19  X20
# 0   NSW   65  415   No   No   0  129.1  ...  111   9.40  12.7    6  3.43    4    1
# 1   TAS  137  415   No   No   0  243.4  ...  104   7.32  12.2    5  3.29    0    0
# 2    SA   73  415   No   No   0  224.4  ...   74   8.68  13.0    2  3.51    1    0
# 3   VIC   84  408  Yes   No   0  299.4  ...   89   8.86   6.6    7  1.78    2    0
# 4   QLD  118  510  Yes   No   0  223.4  ...  118   9.18   6.3    6  1.70    0    0
# 5    WA   75  415  Yes   No   0  166.7  ...  121   8.41  10.1    3  2.73    3    0
# 6    NT  147  415  Yes   No   0  157.0  ...   96   9.53   7.1    6  1.92    0    0
# 7    NT   85  408   No  Yes  27  196.4  ...   75   4.02  13.8    4  3.73    1    0
# 8   VIC  141  415  Yes  Yes  37  258.6  ...   97  14.69  11.2    5  3.02    0    0
# 9   VIC  107  415   No  Yes  26  161.6  ...  103  11.45  13.7    3  3.70    1    0
# ...

# %%
dta_churn.describe() #to describe the columns
# Out:
#                 X2          X3  ...          X19          X20
# count  2500.000000  2500.00000  ...  2500.000000  2500.000000
# mean    100.066000   437.89640  ...     1.553200     0.138800
# std      39.658164    42.75347  ...     1.315394     0.345807
# min       1.000000   408.00000  ...     0.000000     0.000000
# 25%      73.000000   415.00000  ...     1.000000     0.000000
# 50%      99.000000   415.00000  ...     1.000000     0.000000
# 75%     126.250000   510.00000  ...     2.000000     0.000000
# max     243.000000   510.00000  ...     9.000000     1.000000
#
# [8 rows x 17 columns]

# %%
dta_churn.shape # print the shape of dataset
# Out:
# (2500, 20)

# %%
dta_churn.info() #print the information of the dataset
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2500 entries, 0 to 2499
# Data columns (total 20 columns):
# X1     2500 non-null object
# X2     2500 non-null int64
# X3     2500 non-null int64
# X4     2500 non-null object
# X5     2500 non-null object
# X6     2500 non-null int64
# X7     2500 non-null float64
# X8     2500 non-null int64
# X9     2500 non-null float64
# X10    2500 non-null float64
# X11    2500 non-null int64
# X12    2500 non-null float64
# X13    2500 non-null float64
# X14    2500 non-null int64
# X15    2500 non-null float64
# X16    2500 non-null float64
# X17    2500 non-null int64
# X18    2500 non-null float64
# X19    2500 non-null int64
# X20    2500 non-null int64
# dtypes: float64(8), int64(9), object(3)
# memory usage: 390.8+ KB

# %%
predictors = ['X2','X3','X6','X7','X8','X9','X10','X19']
features = dta_churn[predictors]
target = dta_churn.X20

# %%
from sklearn.model_selection import train_test_split

X_train,X_test,y_train,y_test = train_test_split(features,target,test_size=0.25,random_state=0)

# %%
dta_churn.replace(('Yes','No'), (1,0), inplace = True) # to replace Yes/No by 1/0
dta_churn.head(10) #print first 10 data
# Out:
#     X1   X2   X3  X4  X5  X6     X7  ...  X14    X15   X16  X17   X18  X19  X20
# 0  NSW   65  415   0   0   0  129.1  ...  111   9.40  12.7    6  3.43    4    1
# 1  TAS  137  415   0   0   0  243.4  ...  104   7.32  12.2    5  3.29    0    0
# 2   SA   73  415   0   0   0  224.4  ...   74   8.68  13.0    2  3.51    1    0
# 3  VIC   84  408   1   0   0  299.4  ...   89   8.86   6.6    7  1.78    2    0
# 4  QLD  118  510   1   0   0  223.4  ...  118   9.18   6.3    6  1.70    0    0
# 5   WA   75  415   1   0   0  166.7  ...  121   8.41  10.1    3  2.73    3    0
# 6   NT  147  415   1   0   0  157.0  ...   96   9.53   7.1    6  1.92    0    0
# 7   NT   85  408   0   1  27  196.4  ...   75   4.02  13.8    4  3.73    1    0
# 8  VIC  141  415   1   1  37  258.6  ...   97  14.69  11.2    5  3.02    0    0
# 9  VIC  107  415   0   1  26  161.6  ...  103  11.45  13.7    3  3.70    1    0
#
# [10 rows x 20 columns]

# %%
mapping = {'NSW':1, 'SA':2, 'QLD':3, 'NT':4, 'WA':5, 'VIC':6, 'TAS':7} #to change the string value into integer value of row 1
dta_churn.replace({'X1': mapping})
# Out:
#       X1   X2   X3  X4  X5  X6     X7  ...  X14    X15   X16  X17   X18  X19  X20
# 0      1   65  415   0   0   0  129.1  ...  111   9.40  12.7    6  3.43    4    1
# 1      7  137  415   0   0   0  243.4  ...  104   7.32  12.2    5  3.29    0    0
# 2      2   73  415   0   0   0  224.4  ...   74   8.68  13.0    2  3.51    1    0
# 3      6   84  408   1   0   0  299.4  ...   89   8.86   6.6    7  1.78    2    0
# 4      3  118  510   1   0   0  223.4  ...  118   9.18   6.3    6  1.70    0    0
# ...   ..  ...  ...  ..  ..  ..    ...  ...  ...    ...   ...  ...   ...  ...  ...
# 2495   1  103  408   0   0   0  160.8  ...  103  11.44   8.5    3  2.30    1    0
# 2496   3  143  408   0   1  22  141.8  ...  130   8.01   7.8    3  2.11    1    0
# 2497   6   79  408   0   1  32   50.6  ...  121   6.61   4.2    4  1.13    2    0
# 2498   6   89  415   0   0   0  134.9  ...  112   8.89  10.2    5  2.75    1    0
# ...

# %%
dta_churn.info() #print out info
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2500 entries, 0 to 2499
# Data columns (total 20 columns):
# X1     2500 non-null object
# X2     2500 non-null int64
# X3     2500 non-null int64
# X4     2500 non-null int64
# X5     2500 non-null int64
# X6     2500 non-null int64
# X7     2500 non-null float64
# X8     2500 non-null int64
# X9     2500 non-null float64
# X10    2500 non-null float64
# X11    2500 non-null int64
# X12    2500 non-null float64
# X13    2500 non-null float64
# X14    2500 non-null int64
# X15    2500 non-null float64
# X16    2500 non-null float64
# X17    2500 non-null int64
# X18    2500 non-null float64
# X19    2500 non-null int64
# X20    2500 non-null int64
# dtypes: float64(8), int64(11), object(1)
# memory usage: 390.8+ KB

# %%
predictors1 = ['X2','X3','X4','X5','X6','X7','X8','X9','X10','X11','X12','X13','X14','X15','X16','X17','X18','X19',] #to predict the new set of prediction value
features1 = dta_churn[predictors1]
target1 = dta_churn.X20

# %%
print(features1) #print out features
# Out:
#        X2   X3  X4  X5  X6     X7   X8  ...    X13  X14    X15   X16  X17   X18  X19
# 0      65  415   0   0   0  129.1  137  ...  208.8  111   9.40  12.7    6  3.43    4
# 1     137  415   0   0   0  243.4  114  ...  162.6  104   7.32  12.2    5  3.29    0
# 2      73  415   0   0   0  224.4   90  ...  192.8   74   8.68  13.0    2  3.51    1
# 3      84  408   1   0   0  299.4   71  ...  196.9   89   8.86   6.6    7  1.78    2
# 4     118  510   1   0   0  223.4   98  ...  203.9  118   9.18   6.3    6  1.70    0
# ...   ...  ...  ..  ..  ..    ...  ...  ...    ...  ...    ...   ...  ...   ...  ...
# 2495  103  408   0   0   0  160.8   91  ...  254.3  103  11.44   8.5    3  2.30    1
# 2496  143  408   0   1  22  141.8  116  ...  178.1  130   8.01   7.8    3  2.11    1
# 2497   79  408   0   1  32   50.6   62  ...  146.8  121   6.61   4.2    4  1.13    2
# 2498   89  415   0   0   0  134.9   59  ...  197.5  112   8.89  10.2    5  2.75    1
# ...

# %%
 print(target1) #print out target
# Out:
# 0       1
# 1       0
# 2       0
# 3       0
# 4       0
#        ..
# 2495    0
# 2496    0
# 2497    0
# 2498    0
# 2499    0
# Name: X20, Length: 2500, dtype: int64

# %%
from sklearn.model_selection import train_test_split #split the dataset


X_train, X_test, y_train,y_test = train_test_split(features1, target1, test_size=0.50, random_state=0)

# %%
from sklearn.linear_model import LogisticRegression

dta_churn1=LogisticRegression()

dta_churn1.fit(X_train,y_train)

predictors1 = dta_churn1.predict(X_test)
# Out:
# /usr/local/lib/python3.6/dist-packages/sklearn/linear_model/_logistic.py:940: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)

# %%
from sklearn import metrics #import metrics class

cnf_matrix = metrics.confusion_matrix(y_test, predictors1)

cnf_matrix
# Out:
# array([[1060,   19],
#        [ 159,   12]])

# %%
print("Accuracy:", round(metrics.accuracy_score(y_test, predictors1),2)) #print out accuracy
# Out:
# Accuracy: 0.86

# %%
predictors2 = ['X2','X3','X4','X5','X6','X7','X8','X9','X10','X11','X12','X13','X14','X15','X16','X17','X18','X19',]
features2 = dta_churn[predictors]
target2 = dta_churn.X20

# %%
print(features2) # to print features2
# Out:
#        X2   X3  X6     X7   X8     X9    X10  X19
# 0      65  415   0  129.1  137  21.95  228.5    4
# 1     137  415   0  243.4  114  41.38  121.2    0
# 2      73  415   0  224.4   90  38.15  159.5    1
# 3      84  408   0  299.4   71  50.90   61.9    2
# 4     118  510   0  223.4   98  37.98  220.6    0
# ...   ...  ...  ..    ...  ...    ...    ...  ...
# 2495  103  408   0  160.8   91  27.34  155.8    1
# 2496  143  408  22  141.8  116  24.11  167.3    1
# 2497   79  408  32   50.6   62   8.60  201.4    2
# 2498   89  415   0  134.9   59  22.93  156.0    1
# 2499  120  415   0  252.1  110  42.86  226.1    1
#
# [2500 rows x 8 columns]

# %%
print(target2) #to print target2
# Out:
# 0       1
# 1       0
# 2       0
# 3       0
# 4       0
#        ..
# 2495    0
# 2496    0
# 2497    0
# 2498    0
# 2499    0
# Name: X20, Length: 2500, dtype: int64

# %%
from sklearn.model_selection import train_test_split


X_train, X_test, y_train,y_test = train_test_split(features2, target2, test_size=0.25, random_state=0)

# %%
from sklearn.linear_model import LogisticRegression

dta_churn2=LogisticRegression()

dta_churn2.fit(X_train,y_train)

predictors2 = dta_churn2.predict(X_test)

# %%
from sklearn import metrics #inport metrics class

cnf_matrix = metrics.confusion_matrix(y_test, predictors2)

cnf_matrix
# Out:
# array([[543,   4],
#        [ 76,   2]])

# %%
print("Accuracy:", round(metrics.accuracy_score(y_test, predictors2),2)) #to print accuracy
# Out:
# Accuracy: 0.87

# %%
churn = dta_churn2.predict(features)
answers = pd.DataFrame(churn,columns=['prediction'])
answers
# Out:
#       prediction
# 0              0
# 1              0
# 2              0
# 3              0
# 4              0
# ...          ...
# 2495           0
# 2496           0
# 2497           0
# 2498           0
# 2499           0
#
# [2500 rows x 1 columns]

# %%
answers.to_csv('/content/gdrive/My Drive/Colab Notebooks/answers.csv')
